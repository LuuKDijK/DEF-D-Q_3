# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 37     |  |
# | :-------------|:-------------|
# | Luuk van Dijk| 6518702 |
# | Arie Klok| 6548350 |
# | Niels van Meurs| 6190243 |
#
# | Planning Groep: 37     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 12:00 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 14:00 |
# | Pauze 1| 1:00 |
# | Pauze 2| 0 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](1000030726.jpg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |kracht | weegschaal | meten van massa tussen de 0 en 250 gram. Op 1 gram nauwkeurigheid. |
# |magneet | stroommeter (lorentzkracht) | Moet een magnetische kracht kunnen meten tussen 0 en 1 militesla. Nauwkeurigheid van 0.01 militesla |
# |temperatuur | (keuken)thermometer | Moet kunnen meten tussen 35 en 80 graden celcius nauwkeurigheid van 1 graden |
#
#
# Groep 37 heeft gekozen voor sensor kracht, toepassing weegschaal.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Schets van het elektrisch circuit & van de meetopstelling.
#  ![Alt](1000030752.jpg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
# Massa van de gewichtjes
# 2. Over welk bereik ga je deze variabelen veranderen?
# Het bereik gegeven in de criteria: van 0 tot 250 gram
# 3. Wat ga je allemaal meten?
# De stroomsterkte over de variabele weerstand
# 4. Hoeveel metingen ga je doen?
# 10 metingen, interval van 25 gram
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
# Ja

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Meetopstelling, door gebruik te maken van de geodriehoek zal het buigpunt in het midden van de sensor liggen. De kracht zal hierdoor ook hierop gecentreerd worden
#  ![Alt](1000030754.jpg "meetopstelling student")
#
# Om de massa beter te concentreren op de weerstand hebben we gekozen om er een kurk op te plaatsen. Op deze kurk plaatsen wij de gewichten. Doordat dit niet een perfecte oplossing en het onrealistisch zou zijn om aan te nemen dat dit systeem geen ongewenst effect zou hebben op het gewicht dat uitgelezen zou worden hebben wij hier rekening mee gehouden in de error van de waarde.
#
#
# ![Alt](1000030761.jpg "kurk")

# %% [markdown]
# ## *Opdracht 6*: Meten en Fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
massa_planken = np.array([160,198.8, 272.5, 313.3, 40.8, 79.6,109.8, 184.3, 263.9]) # gram
waarde_tabel = np.array([488,  460, 429, 423, 771, 696, 688, 587, 510 ])

# Errorbars
massa_error = 5  # gram
waarde_error = 20   # waarde

plt.figure(figsize=(10,6))
plt.errorbar(massa_planken, waarde_tabel, xerr=massa_error, yerr=waarde_error, fmt='o', capsize=5, label='Meetpunten met errors')
plt.xlabel('Massa (gram)')
plt.ylabel('Waarde')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline

# Fit een lineaire functie y = a*x + b
coefficients = np.polyfit(massa_planken, waarde_tabel, 1)
a, b = coefficients[0], coefficients[1]
fit_line = a * massa_planken + b

# Plot de meetpunten en de fitlijn
plt.figure(figsize=(10, 6))
plt.plot(massa_planken, waarde_tabel, 'o', label='Meetpunten', markersize=8)
plt.plot(massa_planken, fit_line, 'r-', label=f'Fit: y = {a:.2f}x + {b:.2f}')
plt.xlabel('Massa (gram)')
plt.ylabel('Waarde')
plt.legend()
plt.grid(True, alpha=0.3)
plt.title('Kalibratie Meting met Fit')
plt.show()

# Print de fitparameters
print(f"Fitparameters:")
print(f"a (helling) = {a:.4f}")
print(f"b (intercept) = {b:.4f}")
print(f"Vergelijking: y = {a:.4f}*x + {b:.4f}")
# Out:
# Fitparameters:
# a (helling) = -1.2684
# b (intercept) = 790.0754
# Vergelijking: y = -1.2684*x + 790.0754

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# Eerste iteratie
massa_planken = np.array([160, 198.8, 272.5, 313.3, 40.8, 79.6, 109.8, 184.3, 263.9])  # gram
waarde_tabel = np.array([488, 460, 429, 423, 771, 696, 688, 587, 510])

# Tweede iteratie
massa_2e_iteratie = np.array([1250, 3750, 2500, 5000, 7500, 8750, 6250])
waarde_2e_iteratie = np.array([234, 109, 140, 52, 35, 30, 40])

# Errorbars
massa_error = 5  # gram
waarde_error = 20    # waarde

# Combineer beide datasets
massa_gecombineerd = np.concatenate([massa_planken, massa_2e_iteratie])
waarde_gecombineerd = np.concatenate([waarde_tabel, waarde_2e_iteratie])

# Fit logaritmische functie over beide iteraties: y = a*log(x) + b
sorted_indices = np.argsort(massa_gecombineerd)
x_sorted = massa_gecombineerd[sorted_indices]
y_sorted = waarde_gecombineerd[sorted_indices]

# Fit: log scale
coeffs = np.polyfit(np.log10(x_sorted), y_sorted, 1)
fit_line = coeffs[0] * np.log10(x_sorted) + coeffs[1]

plt.figure(figsize=(10, 6))
# Eerste iteratie (blauwe kleur)
plt.errorbar(massa_planken, waarde_tabel, xerr=massa_error, yerr=waarde_error, 
             fmt='o', capsize=5, color='blue', label='1e iteratie', markersize=8)

# Tweede iteratie (groene kleur)
plt.errorbar(massa_2e_iteratie, waarde_2e_iteratie, xerr=massa_error, yerr=waarde_error, 
             fmt='s', capsize=5, color='green', label='2e iteratie', markersize=8)

# Één fitlijn over beide iteraties
plt.plot(x_sorted, fit_line, 'r--', linewidth=2, label=f'Fit: y = {coeffs[0]:.2f}*log(x) + {coeffs[1]:.2f}')

plt.xlabel('Massa (gram)')
plt.ylabel('Waarde')
plt.legend()
plt.grid(True, alpha=0.3)
plt.title('Kalibratie Metingen - Iteratie 1 en 2')
plt.xscale('log')  # Logaritmische schaal voor de x-as
plt.show()

print(f"Fitparameters (beide iteraties gecombineerd):")
print(f"a (helling) = {coeffs[0]:.4f}")
print(f"b (intercept) = {coeffs[1]:.4f}")
print(f"Vergelijking: y = {coeffs[0]:.4f}*log(x) + {coeffs[1]:.4f}")
# Out:
# Fitparameters (beide iteraties gecombineerd):
# a (helling) = -328.2502
# b (intercept) = 1280.0576
# Vergelijking: y = -328.2502*log(x) + 1280.0576

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# We hebben een tweede Iteratie gedaan, omdat de punten geen logaritmische schaal volgden en we dachten dat dat kwam doordat we te kleine gewichten gebruikte. om dit op te lossen, moetsten de massa moet een stuk groter zijn dan in eerste instantie verwacht om een kloppende grafiek te krijgen. Na het vergroten van de massa kon er een passende curvefit gemaakt worden. . Dit bleek ook te kloppen, zoals te zien in de curvefit hierboven.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Concluderend, het is mogelijk om een weegschaal te maken door gebruik te maken van een druksensor die aangesloten is op een arduino. Echter, is het niet mogelijk om een weegschaal te maken die werkt en tegelijkertijd aan onze criteria (het meten van massa's tussen de 0 en 250 gram. Op 1 gram nauwkeurigheid.) voldoet, omdat de druksensor een heel groot meetbereik heeft wat ervoor zorgt dat er niet genoeg discrete meetstappen zijn in deze regio. ook heeft onze opstelling van de weegschaal een sterke ruis. Door de vele schommelingen die in de data zitten, is het lastig om een exacte waarde te vinden. Door deze laatste reden is ook ons criterium van een nauwkeurigheid hebben van 1 gram niet bereikt en is het dus niet mogelijk om een weegschaal te maken met een meetbereik tussen de 0 en 250 gram en een nauwkeurigheid van 1 gram.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Meetopstelling, door gebruik te maken van de geodriehoek zal het buigpunt in het midden van de sensor liggen. De kracht zal hierdoor ook hierop gecentreerd worden
#  ![Alt](1000030754.jpg "meetopstelling student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |kracht | weegschaal | meten van massa tussen de 0 en 250 gram. Op 1 gram nauwkeurigheid. |
# |magneet | stroommeter (lorentzkracht) | Moet een magnetische kracht kunnen meten tussen 0 en 1 militesla. Nauwkeurigheid van 0.01 militesla |
# |temperatuur | (keuken)thermometer | Moet kunnen meten tussen 35 en 80 graden celcius nauwkeurigheid van 1 graden |
#
#
# Groep 37 heeft gekozen voor sensor kracht, toepassing weegschaal.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |kracht | weegschaal | meten van massa tussen de 0 en 250 gram. Op 1 gram nauwkeurigheid. |
# |magneet | stroommeter (lorentzkracht) | Moet een magnetische kracht kunnen meten tussen 0 en 1 militesla. Nauwkeurigheid van 0.01 militesla |
# |temperatuur | (keuken)thermometer | Moet kunnen meten tussen 35 en 80 graden celcius nauwkeurigheid van 1 graden |
#
#
# Groep 37 heeft gekozen voor sensor kracht, toepassing weegschaal.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Meetopstelling, door gebruik te maken van de geodriehoek zal het buigpunt in het midden van de sensor liggen. De kracht zal hierdoor ook hierop gecentreerd worden
#  ![Alt](1000030754.jpg "meetopstelling student")
#
# Om de massa beter te concentreren op de weerstand hebben we gekozen om er een kurk op te plaatsen. Op deze kurk plaatsen wij de gewichten. Doordat dit niet een perfecte oplossing en het onrealistisch zou zijn om aan te nemen dat dit systeem geen ongewenst effect zou hebben op het gewicht dat uitgelezen zou worden hebben wij hier rekening mee gehouden in de error van de waarde.
#
#
# ![Alt](1000030761.jpg "kurk")

# %% [markdown]
# ## *Opdracht 6*: Meten en Fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# Eerste iteratie
massa_planken = np.array([160, 198.8, 272.5, 313.3, 40.8, 79.6, 109.8, 184.3, 263.9])  # gram
waarde_tabel = np.array([488, 460, 429, 423, 771, 696, 688, 587, 510])

# Tweede iteratie
massa_2e_iteratie = np.array([1250, 3750, 2500, 5000, 7500, 8750, 6250])
waarde_2e_iteratie = np.array([234, 109, 140, 52, 35, 30, 40])

# Errorbars
massa_error = 5  # gram
waarde_error = 20    # waarde

# Combineer beide datasets
massa_gecombineerd = np.concatenate([massa_planken, massa_2e_iteratie])
waarde_gecombineerd = np.concatenate([waarde_tabel, waarde_2e_iteratie])

# Fit logaritmische functie over beide iteraties: y = a*log(x) + b
sorted_indices = np.argsort(massa_gecombineerd)
x_sorted = massa_gecombineerd[sorted_indices]
y_sorted = waarde_gecombineerd[sorted_indices]

# Fit: log scale
coeffs = np.polyfit(np.log10(x_sorted), y_sorted, 1)
fit_line = coeffs[0] * np.log10(x_sorted) + coeffs[1]

plt.figure(figsize=(10, 6))
# Eerste iteratie (blauwe kleur)
plt.errorbar(massa_planken, waarde_tabel, xerr=massa_error, yerr=waarde_error, 
             fmt='o', capsize=5, color='blue', label='1e iteratie', markersize=8)

# Tweede iteratie (groene kleur)
plt.errorbar(massa_2e_iteratie, waarde_2e_iteratie, xerr=massa_error, yerr=waarde_error, 
             fmt='s', capsize=5, color='green', label='2e iteratie', markersize=8)

# Één fitlijn over beide iteraties
plt.plot(x_sorted, fit_line, 'r--', linewidth=2, label=f'Fit: y = {coeffs[0]:.2f}*log(x) + {coeffs[1]:.2f}')

plt.xlabel('Massa (gram)')
plt.ylabel('Waarde')
plt.legend()
plt.grid(True, alpha=0.3)
plt.title('Kalibratie Metingen - Iteratie 1 en 2')
plt.xscale('log')  # Logaritmische schaal voor de x-as
plt.show()

print(f"Fitparameters (beide iteraties gecombineerd):")
print(f"a (helling) = {coeffs[0]:.4f}")
print(f"b (intercept) = {coeffs[1]:.4f}")
print(f"Vergelijking: y = {coeffs[0]:.4f}*log(x) + {coeffs[1]:.4f}")
# Out:
# Fitparameters (beide iteraties gecombineerd):
# a (helling) = -328.2502
# b (intercept) = 1280.0576
# Vergelijking: y = -328.2502*log(x) + 1280.0576

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Concluderend, het is mogelijk om een weegschaal te maken door gebruik te maken van een druksensor die aangesloten is op een arduino. Echter, is het niet mogelijk om een weegschaal te maken die werkt en tegelijkertijd aan onze criteria (het meten van massa's tussen de 0 en 250 gram. Op 1 gram nauwkeurigheid.) voldoet, omdat de druksensor een heel groot meetbereik heeft wat ervoor zorgt dat er niet genoeg discrete meetstappen zijn in deze regio. ook heeft onze opstelling van de weegschaal een sterke ruis. Door de vele schommelingen die in de data zitten, is het lastig om een exacte waarde te vinden. Door deze laatste reden is ook ons criterium van een nauwkeurigheid hebben van 1 gram niet bereikt en is het dus niet mogelijk om een weegschaal te maken met een meetbereik tussen de 0 en 250 gram en een nauwkeurigheid van 1 gram.
